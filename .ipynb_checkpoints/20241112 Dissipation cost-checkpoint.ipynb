# %% [markdown]
# # Computing the effect of a cost of dissipation in the fitness function

# %% [markdown]
# #### Importing modules

# %%
import numpy as np
from numpy.linalg import inv
from numpy.linalg import pinv
from numpy.linalg import eig
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
import palettable as pal
import itertools
import random

import copy
from tqdm import tqdm
from matplotlib.ticker import LogLocator
from matplotlib.ticker import ScalarFormatter
from scipy import linalg as LA

# %%
import seaborn as sns
# %matplotlib inline
sns.set_context("talk",rc={"font.size":16,"axes.titlesize":16,"axes.labelsize":20})
sns.set_style("whitegrid",{"grid.color": '.9', 'grid.linestyle': '--','axes.edgecolor': '.6', \
                           'xtick.bottom': True,'ytick.left': True})

# %%
from physics import *
from network import *
from tools import save_vars
from evolution import *

# %% [markdown]
# ## Curves at different dissipation costs

# %% [markdown]
# |Number of nodes ($N$) | $T$ | $t_{\rm{stall}}$| $\delta$| size | dsize|
# |-----------|-----|-----------------|---------|------|------|
# |3| $10^{-3}$| $10^3$| 0.4| 7| 0.2|

# %%
N = 3       #  Size of the network
delta = 0.4
init = 0      # Definition of the initial state
size = 7
dsize = 0.2
maxsize = 5

eps_v, eps_b, p_0, end, V, B, mu, k_r, k_w, V_0, B_0, mu_0 = initialise_network(N, delta, init, size, dsize, maxsize)
# Out:
# Genome: [-7.00000000e+00 -6.80000000e+00 -6.60000000e+00 -6.40000000e+00
#  -6.20000000e+00 -6.00000000e+00 -5.80000000e+00 -5.60000000e+00
#  -5.40000000e+00 -5.20000000e+00 -5.00000000e+00 -4.80000000e+00
#  -4.60000000e+00 -4.40000000e+00 -4.20000000e+00 -4.00000000e+00
#  -3.80000000e+00 -3.60000000e+00 -3.40000000e+00 -3.20000000e+00
#  -3.00000000e+00 -2.80000000e+00 -2.60000000e+00 -2.40000000e+00
#  -2.20000000e+00 -2.00000000e+00 -1.80000000e+00 -1.60000000e+00
#  -1.40000000e+00 -1.20000000e+00 -1.00000000e+00 -8.00000000e-01
#  -6.00000000e-01 -4.00000000e-01 -2.00000000e-01  6.21724894e-15
#   2.00000000e-01  4.00000000e-01  6.00000000e-01  8.00000000e-01
#   1.00000000e+00  1.20000000e+00  1.40000000e+00  1.60000000e+00
#   1.80000000e+00  2.00000000e+00  2.20000000e+00  2.40000000e+00
#   2.60000000e+00  2.80000000e+00  3.00000000e+00  3.20000000e+00
#   3.40000000e+00  3.60000000e+00  3.80000000e+00  4.00000000e+00
#   4.20000000e+00  4.40000000e+00  4.60000000e+00  4.80000000e+00] Length: 60
# Error at initialisation: 0.6703200460356379 e^{-\Delta}: 0.6703200460356393
# Sum over rows: [3.32850067e-17 0.00000000e+00 0.00000000e+00]

# %%
n_samples = 5

T = 1e-3  # Evolution temperature
t_s = [1e3]
mcsteps = 10000
track_e, track_S, track_t, track_ea, track_Sa, track_ta, = [ [] for i in range(6)]

for t_stall in t_s:
    

    #q_list = [5e3, 1e3, 1e2, 0.5, 0]
    q_list = [5e3, 1e3, 0]
    track_q = []
    for q in q_list:
        print('First search', q, 'T_stall', t_stall)
        track_error_s, track_speed_s, track_fpt_s, track_fptw_s, track_mu_s, \
        track_ent_s, track_time_s, track_k_s = evolve(N, L, mcsteps, T, t_stall, q, delta, n_samples, \
                                                      size, dsize, maxsize)

        track_e.append(track_error_s)
        track_S.append(track_ent_s)
        track_t.append(track_time_s)

    track_ea.append(track_e)
    track_Sa.append(track_S)
    track_ta.append(track_t)
# Out:
# First search 5000.0 T_stall 1000.0
# First search 1000.0 T_stall 1000.0
# First search 0 T_stall 1000.0

# %%
fig, axs = plt.subplots(2,2, figsize=(10, 8.5), sharex=True)

for idx in range(1):
    time = np.asarray(track_t[idx][0])+1

    # Largest cost to entropy production
    idx_q = 0
    idx_sample = 3
    axs[1,1].plot(np.asarray(track_t[idx_q][idx_sample])+1, track_S[idx_q][idx_sample], '-o', \
                  color=pal.colorbrewer.sequential.PuBu_6.mpl_colors[1], markersize=4)

    axs[0,1].plot(np.asarray(track_t[idx_q][idx_sample])+1, track_e[idx_q][idx_sample], '-o', \
                  color=pal.colorbrewer.sequential.PuBu_6.mpl_colors[1], markersize=7)

    # Medium cost to entropy production
    idx_q = 1
    idx_sample = 1 # Change the idx_sample to find a sensible trajectory, this value of cost
                   # is right at the crossover between allowing or not for error correction
    axs[1,1].plot(np.asarray(track_t[idx_q][idx_sample])+1, track_S[idx_q][idx_sample], '-o', \
                  color=pal.colorbrewer.sequential.PuBu_6.mpl_colors[3], markersize=4)

    axs[0,1].plot(np.asarray(track_t[idx_q][idx_sample])+1, track_e[idx_q][idx_sample], '-o', \
                  color=pal.colorbrewer.sequential.PuBu_6.mpl_colors[3], markersize=7)

    # No cost to entropy production
    idx_q = 2
    idx_sample = 2
    axs[1,1].plot(np.asarray(track_t[idx_q][idx_sample])+1, track_S[idx_q][idx_sample], '-o', \
                  color=pal.colorbrewer.sequential.PuBu_6.mpl_colors[5], markersize=4)

    axs[0,1].plot(np.asarray(track_t[idx_q][idx_sample])+1, track_e[idx_q][idx_sample], '-o', \
                  color=pal.colorbrewer.sequential.PuBu_6.mpl_colors[5], markersize=7)


axs[0,0].set_ylabel('Time to copy strand')
axs[0,0].set_yscale('log')
axs[0,0].set_xscale('log')

#axs[0,0].set_ylim([2e3,1e4])
axs[0,0].set_xlim([1.5e2,1e4])
axs[0,0].set_ylim([4e2,8e2])


axs[0,1].set_ylabel(r'Mutation rate')
axs[0,1].set_yscale('log')
axs[0,1].set_xscale('log')
xlim = axs[0,0].get_xlim()
axs[0,1].plot(xlim, [np.exp(-delta), np.exp(-delta)], '--', color = 'black', linewidth=3, alpha=0.6, label=r'$e^{-\Delta}$')
axs[0,1].plot(xlim, [np.exp(-(N-int(N/2))*delta), np.exp(-(N-int(N/2))*delta)], ':', color=(0.85, 0.37, 0.01), linewidth=3, \
              alpha=0.6, label=r'$e^{-%d\Delta}$'%((N-int(N/2))))
# axs[0,1].set_xlim([1e1,1e3])
axs[0,1].legend(frameon=False)

axs[1,1].set_ylabel("Entropy dissipation")
axs[1,1].set_xlabel('MC steps')
axs[1,1].set_xscale('log')
#axs[1,1].set_yscale('log')


axs[1,0].set_ylabel('Time to insert base')
axs[1,0].set_xlabel('MC steps')
axs[1,0].set_yscale('log')
axs[1,0].set_xscale('log')
axs[1,0].set_ylim([0.8e0,2e2])


fig.tight_layout()
plt.savefig('dissipation_curves_N%d_tstall%d_T_%d.pdf' % (N, t_stall, T) )
plt.show()

# %% [markdown]
# ### Crossover cost as function of stalling time

# %% [markdown]
# **Simulation is time-costly, load the data saved in the following**

# %% [markdown]
# For different values of stalling time, we swipe through different strength of dissipation cost to identify the value at which discrimination (or dissipation) starts to occur.

# %%
N = 3       #  Size of the network
delta = 0.4   # Defining the perturbation (quenched): the kinetics difference between R and W \
              #is fixed to be at most e^delta (-delta < eps < delta)
init = 0      # Definition of the initial state
size = 7
dsize = 0.2
maxsize = 5

eps_v, eps_b, p_0, end, V, B, mu, k_r, k_w, V_0, B_0, mu_0 = initialise_network(N, delta, init, size, dsize, maxsize)
# Out:
# Genome: [-7.00000000e+00 -6.80000000e+00 -6.60000000e+00 -6.40000000e+00
#  -6.20000000e+00 -6.00000000e+00 -5.80000000e+00 -5.60000000e+00
#  -5.40000000e+00 -5.20000000e+00 -5.00000000e+00 -4.80000000e+00
#  -4.60000000e+00 -4.40000000e+00 -4.20000000e+00 -4.00000000e+00
#  -3.80000000e+00 -3.60000000e+00 -3.40000000e+00 -3.20000000e+00
#  -3.00000000e+00 -2.80000000e+00 -2.60000000e+00 -2.40000000e+00
#  -2.20000000e+00 -2.00000000e+00 -1.80000000e+00 -1.60000000e+00
#  -1.40000000e+00 -1.20000000e+00 -1.00000000e+00 -8.00000000e-01
#  -6.00000000e-01 -4.00000000e-01 -2.00000000e-01  6.21724894e-15
#   2.00000000e-01  4.00000000e-01  6.00000000e-01  8.00000000e-01
#   1.00000000e+00  1.20000000e+00  1.40000000e+00  1.60000000e+00
#   1.80000000e+00  2.00000000e+00  2.20000000e+00  2.40000000e+00
#   2.60000000e+00  2.80000000e+00  3.00000000e+00  3.20000000e+00
#   3.40000000e+00  3.60000000e+00  3.80000000e+00  4.00000000e+00
#   4.20000000e+00  4.40000000e+00  4.60000000e+00  4.80000000e+00] Length: 60
# Error at initialisation: 0.6703200460356393 e^{-\Delta}: 0.6703200460356393
# Sum over rows: [ 1.11022302e-16 -4.06575815e-20  0.00000000e+00]

# %% [markdown]
# ### Decrease in error rate as criterion

# %% [markdown]
# The code below can be used to calculate the crossover with error rate as criterion. It takes some time to run since it explores different samples and stalling times, the trajectories used are saved and can be loaded.

# %%
n_samples = 5
n_cycles = 6
mcsteps = 5000
percent = 0.5
T = 1e-3  # Evolution temperature

#t_s = [5e1, 1e2, 3e2, 1e3, 3e3, 1e4, 3e4, 1e5, 1e6]
t_s = [5e1, 1e2, 3e2, 1e3, 3e3, 1e4, 3e4]
track_e, track_S, cost, stalling = [ [] for i in range(4)]


for t_stall in t_s:
    
    q_list = [1e5, 1e4, 1e3, 1e2, 1e1, 0]
    track_q = []
    for q in q_list:
        print('First search', q, 'T_stall', t_stall)
        track_error_s, track_speed_s, track_fpt_s, track_fptw_s, track_mu_s, \
        track_ent_s, track_time_s, track_k_s = evolve(N, L, mcsteps, T, t_stall, q, delta, n_samples, \
                                                      size, dsize, maxsize)

        track_e.append(track_error_s)
        track_S.append(track_ent_s)

        error_drop = []
        for s in range(n_samples):
            tmp =  np.asarray(track_error_s[s])[0] - np.asarray(track_error_s[s])[-1]
            error_drop.append(tmp)

        threshold = percent*(np.exp(-delta) - np.exp(-(N-int(N/2))*delta))
        if any(y > threshold for y in error_drop):
            print("Cost: ", q, 'T_stall', t_stall)
            track_q.append(q)
            break

    for cycles in range(n_cycles):
        if track_q[-1] != 0:
            kk = [6, 5, 4, 3, 2, 1, -1]
        if track_q[-1] == 0:
            kk = [6, 5, 4, 3, 2, 1, 0.1]
        if (cycles==1)*(track_q[-1] < 1e1):
            break
            
        a = []
        for k in range(len(kk)):
            if track_q[-1] != 0:
                a.append( track_q[-1] + kk[k]*0.1*track_q[-1] )
            if track_q[-1] == 0:
                a.append( track_q[-1] + kk[k] )
        print('New list of costs: ', a)

        for q in q_list:   
            print('Cycle %d search'%(cycles), q, 'T_stall', t_stall)

            track_error_s, track_speed_s, track_fpt_s, track_fptw_s, track_mu_s, \
            track_ent_s, track_time_s, track_k_s = evolve(N, L, mcsteps, T, t_stall, q, delta, n_samples, \
                                                          size, dsize, maxsize)

            track_e.append(track_error_s)
            track_S.append(track_ent_s)

            # Quantifying the error drop
            error_drop = []
            for s in range(n_samples):
                tmp =  np.asarray(track_error_s[s])[0] - np.asarray(track_error_s[s])[-1]
                error_drop.append(tmp)

            threshold = percent*(np.exp(-delta) - np.exp(-(N-int(N/2))*delta))
            if any(y > threshold for y in error_drop):
                print("Cost: ", q, 'T_stall', t_stall)
                track_q.append(q)
                break
    cost.append(track_q[-1])
    stalling.append(t_stall)
# Out:
# First search 100000.0 T_stall 50.0
# First search 10000.0 T_stall 50.0
# First search 1000.0 T_stall 50.0
# First search 100.0 T_stall 50.0
# First search 10.0 T_stall 50.0
# First search 0 T_stall 50.0
# Cost:  0 T_stall 50.0
# New list of costs:  [6, 5, 4, 3, 2, 1, 0.1]
# Cycle 0 search 6 T_stall 50.0
# Cycle 0 search 5 T_stall 50.0
# Cycle 0 search 4 T_stall 50.0
# Cycle 0 search 3 T_stall 50.0
# Cycle 0 search 2 T_stall 50.0
# Cycle 0 search 1 T_stall 50.0
# Cost:  1 T_stall 50.0
# First search 100000.0 T_stall 100.0
# First search 10000.0 T_stall 100.0
# First search 1000.0 T_stall 100.0
# First search 100.0 T_stall 100.0
# First search 10.0 T_stall 100.0
# Cost:  10.0 T_stall 100.0
# New list of costs:  [16.0, 15.0, 14.0, 13.0, 12.0, 11.0, 9.0]
# Cycle 0 search 16.0 T_stall 100.0
# Cycle 0 search 15.0 T_stall 100.0
# Cycle 0 search 14.0 T_stall 100.0
# Cycle 0 search 13.0 T_stall 100.0
# Cycle 0 search 12.0 T_stall 100.0
# Cycle 0 search 11.0 T_stall 100.0
# Cycle 0 search 9.0 T_stall 100.0
# Cost:  9.0 T_stall 100.0
# First search 100000.0 T_stall 300.0
# First search 10000.0 T_stall 300.0
# First search 1000.0 T_stall 300.0
# First search 100.0 T_stall 300.0
# Cost:  100.0 T_stall 300.0
# New list of costs:  [160.0, 150.0, 140.0, 130.0, 120.0, 110.0, 90.0]
# Cycle 0 search 160.0 T_stall 300.0
# Cycle 0 search 150.0 T_stall 300.0
# Cycle 0 search 140.0 T_stall 300.0
# Cycle 0 search 130.0 T_stall 300.0
# Cost:  130.0 T_stall 300.0
# New list of costs:  [208.0, 195.0, 182.0, 169.0, 156.0, 143.0, 117.0]
# Cycle 1 search 208.0 T_stall 300.0
# Cycle 1 search 195.0 T_stall 300.0
# Cycle 1 search 182.0 T_stall 300.0
# Cycle 1 search 169.0 T_stall 300.0
# Cycle 1 search 156.0 T_stall 300.0
# Cycle 1 search 143.0 T_stall 300.0
# Cycle 1 search 117.0 T_stall 300.0
# Cost:  117.0 T_stall 300.0
# New list of costs:  [187.20000000000002, 175.5, 163.8, 152.10000000000002, 140.4, 128.7, 105.3]
# Cycle 2 search 187.20000000000002 T_stall 300.0
# Cycle 2 search 175.5 T_stall 300.0
# Cycle 2 search 163.8 T_stall 300.0
# Cycle 2 search 152.10000000000002 T_stall 300.0
# Cycle 2 search 140.4 T_stall 300.0
# Cycle 2 search 128.7 T_stall 300.0
# Cost:  128.7 T_stall 300.0
# New list of costs:  [205.92, 193.04999999999998, 180.17999999999998, 167.31, 154.44, 141.57, 115.82999999999998]
# Cycle 3 search 205.92 T_stall 300.0
# Cycle 3 search 193.04999999999998 T_stall 300.0
# Cycle 3 search 180.17999999999998 T_stall 300.0
# Cycle 3 search 167.31 T_stall 300.0
# Cycle 3 search 154.44 T_stall 300.0
# Cycle 3 search 141.57 T_stall 300.0
# Cycle 3 search 115.82999999999998 T_stall 300.0
# Cost:  115.82999999999998 T_stall 300.0
# New list of costs:  [185.32799999999997, 173.74499999999998, 162.16199999999998, 150.57899999999998, 138.99599999999998, 127.41299999999998, 104.24699999999999]
# Cycle 4 search 185.32799999999997 T_stall 300.0
# Cycle 4 search 173.74499999999998 T_stall 300.0
# Cycle 4 search 162.16199999999998 T_stall 300.0
# Cycle 4 search 150.57899999999998 T_stall 300.0
# Cycle 4 search 138.99599999999998 T_stall 300.0
# Cost:  138.99599999999998 T_stall 300.0
# New list of costs:  [222.3936, 208.49399999999997, 194.59439999999998, 180.6948, 166.79519999999997, 152.89559999999997, 125.09639999999999]
# Cycle 5 search 222.3936 T_stall 300.0
# Cycle 5 search 208.49399999999997 T_stall 300.0
# Cycle 5 search 194.59439999999998 T_stall 300.0
# Cycle 5 search 180.6948 T_stall 300.0
# Cycle 5 search 166.79519999999997 T_stall 300.0
# Cycle 5 search 152.89559999999997 T_stall 300.0
# Cycle 5 search 125.09639999999999 T_stall 300.0
# Cost:  125.09639999999999 T_stall 300.0
# First search 100000.0 T_stall 1000.0
# First search 10000.0 T_stall 1000.0
# First search 1000.0 T_stall 1000.0
# Cost:  1000.0 T_stall 1000.0
# New list of costs:  [1600.0, 1500.0, 1400.0, 1300.0, 1200.0, 1100.0, 900.0]
# Cycle 0 search 1600.0 T_stall 1000.0
# Cycle 0 search 1500.0 T_stall 1000.0
# Cost:  1500.0 T_stall 1000.0
# New list of costs:  [2400.0, 2250.0, 2100.0, 1950.0, 1800.0, 1650.0, 1350.0]
# Cycle 1 search 2400.0 T_stall 1000.0
# Cycle 1 search 2250.0 T_stall 1000.0
# Cycle 1 search 2100.0 T_stall 1000.0
# Cycle 1 search 1950.0 T_stall 1000.0
# Cycle 1 search 1800.0 T_stall 1000.0
# Cost:  1800.0 T_stall 1000.0
# New list of costs:  [2880.0, 2700.0, 2520.0, 2340.0, 2160.0, 1980.0, 1620.0]
# Cycle 2 search 2880.0 T_stall 1000.0
# Cycle 2 search 2700.0 T_stall 1000.0
# Cycle 2 search 2520.0 T_stall 1000.0
# Cycle 2 search 2340.0 T_stall 1000.0
# Cycle 2 search 2160.0 T_stall 1000.0
# Cycle 2 search 1980.0 T_stall 1000.0
# Cycle 2 search 1620.0 T_stall 1000.0
# Cost:  1620.0 T_stall 1000.0
# New list of costs:  [2592.0, 2430.0, 2268.0, 2106.0, 1944.0, 1782.0, 1458.0]
# Cycle 3 search 2592.0 T_stall 1000.0
# Cycle 3 search 2430.0 T_stall 1000.0
# Cycle 3 search 2268.0 T_stall 1000.0
# Cycle 3 search 2106.0 T_stall 1000.0
# Cycle 3 search 1944.0 T_stall 1000.0
# Cycle 3 search 1782.0 T_stall 1000.0
# Cost:  1782.0 T_stall 1000.0
# New list of costs:  [2851.2, 2673.0, 2494.8, 2316.6, 2138.4, 1960.2, 1603.8]
# Cycle 4 search 2851.2 T_stall 1000.0
# Cycle 4 search 2673.0 T_stall 1000.0
# Cycle 4 search 2494.8 T_stall 1000.0
# Cycle 4 search 2316.6 T_stall 1000.0
# Cycle 4 search 2138.4 T_stall 1000.0
# Cycle 4 search 1960.2 T_stall 1000.0
# Cycle 4 search 1603.8 T_stall 1000.0
# New list of costs:  [2851.2, 2673.0, 2494.8, 2316.6, 2138.4, 1960.2, 1603.8]
# Cycle 5 search 2851.2 T_stall 1000.0
# Cycle 5 search 2673.0 T_stall 1000.0
# Cycle 5 search 2494.8 T_stall 1000.0
# Cycle 5 search 2316.6 T_stall 1000.0
# Cycle 5 search 2138.4 T_stall 1000.0
# Cycle 5 search 1960.2 T_stall 1000.0
# Cycle 5 search 1603.8 T_stall 1000.0
# First search 100000.0 T_stall 3000.0
# First search 10000.0 T_stall 3000.0
# Cost:  10000.0 T_stall 3000.0
# New list of costs:  [16000.0, 15000.0, 14000.0, 13000.0, 12000.0, 11000.0, 9000.0]
# Cycle 0 search 16000.0 T_stall 3000.0
# Cycle 0 search 15000.0 T_stall 3000.0
# Cycle 0 search 14000.0 T_stall 3000.0
# Cycle 0 search 13000.0 T_stall 3000.0
# Cost:  13000.0 T_stall 3000.0
# New list of costs:  [20800.0, 19500.0, 18200.0, 16900.0, 15600.0, 14300.0, 11700.0]
# Cycle 1 search 20800.0 T_stall 3000.0
# Cycle 1 search 19500.0 T_stall 3000.0
# Cycle 1 search 18200.0 T_stall 3000.0
# Cost:  18200.0 T_stall 3000.0
# New list of costs:  [29120.0, 27300.0, 25480.0, 23660.0, 21840.0, 20020.0, 16380.0]
# Cycle 2 search 29120.0 T_stall 3000.0
# Cycle 2 search 27300.0 T_stall 3000.0
# Cycle 2 search 25480.0 T_stall 3000.0
# Cycle 2 search 23660.0 T_stall 3000.0
# Cycle 2 search 21840.0 T_stall 3000.0
# Cycle 2 search 20020.0 T_stall 3000.0
# Cycle 2 search 16380.0 T_stall 3000.0
# Cost:  16380.0 T_stall 3000.0
# New list of costs:  [26208.0, 24570.0, 22932.0, 21294.0, 19656.0, 18018.0, 14742.0]
# Cycle 3 search 26208.0 T_stall 3000.0
# Cycle 3 search 24570.0 T_stall 3000.0
# Cycle 3 search 22932.0 T_stall 3000.0
# Cycle 3 search 21294.0 T_stall 3000.0
# Cycle 3 search 19656.0 T_stall 3000.0
# Cycle 3 search 18018.0 T_stall 3000.0
# Cycle 3 search 14742.0 T_stall 3000.0
# New list of costs:  [26208.0, 24570.0, 22932.0, 21294.0, 19656.0, 18018.0, 14742.0]
# Cycle 4 search 26208.0 T_stall 3000.0
# Cycle 4 search 24570.0 T_stall 3000.0
# Cycle 4 search 22932.0 T_stall 3000.0
# Cycle 4 search 21294.0 T_stall 3000.0
# Cycle 4 search 19656.0 T_stall 3000.0
# Cycle 4 search 18018.0 T_stall 3000.0
# Cycle 4 search 14742.0 T_stall 3000.0
# New list of costs:  [26208.0, 24570.0, 22932.0, 21294.0, 19656.0, 18018.0, 14742.0]
# Cycle 5 search 26208.0 T_stall 3000.0
# Cycle 5 search 24570.0 T_stall 3000.0
# Cycle 5 search 22932.0 T_stall 3000.0
# Cycle 5 search 21294.0 T_stall 3000.0
# Cycle 5 search 19656.0 T_stall 3000.0
# Cost:  19656.0 T_stall 3000.0
# First search 100000.0 T_stall 10000.0
# First search 10000.0 T_stall 10000.0
# Cost:  10000.0 T_stall 10000.0
# New list of costs:  [16000.0, 15000.0, 14000.0, 13000.0, 12000.0, 11000.0, 9000.0]
# Cycle 0 search 16000.0 T_stall 10000.0
# Cost:  16000.0 T_stall 10000.0
# New list of costs:  [25600.0, 24000.0, 22400.0, 20800.0, 19200.0, 17600.0, 14400.0]
# Cycle 1 search 25600.0 T_stall 10000.0
# Cost:  25600.0 T_stall 10000.0
# New list of costs:  [40960.0, 38400.0, 35840.0, 33280.0, 30720.0, 28160.0, 23040.0]
# Cycle 2 search 40960.0 T_stall 10000.0
# Cost:  40960.0 T_stall 10000.0
# New list of costs:  [65536.0, 61440.0, 57344.0, 53248.0, 49152.0, 45056.0, 36864.0]
# Cycle 3 search 65536.0 T_stall 10000.0
# Cycle 3 search 61440.0 T_stall 10000.0
# Cost:  61440.0 T_stall 10000.0
# New list of costs:  [98304.0, 92160.0, 86016.0, 79872.0, 73728.0, 67584.0, 55296.0]
# Cycle 4 search 98304.0 T_stall 10000.0
# Cycle 4 search 92160.0 T_stall 10000.0
# Cycle 4 search 86016.0 T_stall 10000.0
# Cycle 4 search 79872.0 T_stall 10000.0
# Cost:  79872.0 T_stall 10000.0
# New list of costs:  [127795.20000000001, 119808.0, 111820.8, 103833.6, 95846.4, 87859.2, 71884.8]
# Cycle 5 search 127795.20000000001 T_stall 10000.0
# Cost:  127795.20000000001 T_stall 10000.0
# First search 100000.0 T_stall 30000.0
# Cost:  100000.0 T_stall 30000.0
# New list of costs:  [160000.0, 150000.0, 140000.0, 130000.0, 120000.0, 110000.0, 90000.0]
# Cycle 0 search 160000.0 T_stall 30000.0
# Cost:  160000.0 T_stall 30000.0
# New list of costs:  [256000.0, 240000.0, 224000.0, 208000.0, 192000.0, 176000.0, 144000.0]
# Cycle 1 search 256000.0 T_stall 30000.0
# Cost:  256000.0 T_stall 30000.0
# New list of costs:  [409600.0, 384000.0, 358400.0, 332800.0, 307200.0, 281600.0, 230400.0]
# Cycle 2 search 409600.0 T_stall 30000.0
# Cost:  409600.0 T_stall 30000.0
# New list of costs:  [655360.0, 614400.0, 573440.0, 532480.0, 491520.0, 450560.0, 368640.0]
# Cycle 3 search 655360.0 T_stall 30000.0
# Cycle 3 search 614400.0 T_stall 30000.0
# Cost:  614400.0 T_stall 30000.0
# New list of costs:  [983040.0, 921600.0, 860160.0, 798720.0, 737280.0, 675840.0, 552960.0]
# Cycle 4 search 983040.0 T_stall 30000.0
# Cost:  983040.0 T_stall 30000.0
# New list of costs:  [1572864.0, 1474560.0, 1376256.0, 1277952.0, 1179648.0, 1081344.0, 884736.0]
# Cycle 5 search 1572864.0 T_stall 30000.0
# Cycle 5 search 1474560.0 T_stall 30000.0
# Cycle 5 search 1376256.0 T_stall 30000.0
# Cycle 5 search 1277952.0 T_stall 30000.0
# Cycle 5 search 1179648.0 T_stall 30000.0
# Cost:  1179648.0 T_stall 30000.0

# %%
# import pickle
# trajs = [stalling, cost]
# with open('discrimination_cost_50p.pickle', 'wb') as handle:
#     pickle.dump(trajs, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# #### Increase in entropy as criterion

# %% [markdown]
# The code below can be used to calculate the crossover with entropy production rate as criterion. It takes some time to run since it explores different samples and stalling times, the trajectories used are saved and can be loaded.

# %%
n_samples = 5
n_cycles = 6
percent = 0.5
T = 1e-3  # Evolution temperature
#t_s = [5e1, 1e2, 3e2, 1e3, 3e3, 1e4, 3e4, 1e5, 3e5]
t_s = [5e1, 1e2, 3e2, 1e3, 3e3, 1e4, 3e4]
track_e, track_S, track_t, cost, stalling = [ [] for i in range(5)]

for t_stall in t_s:
    
    if t_stall > 1e3:
        mcsteps = int(5e3)
        threshold = 1e-4
    if (t_stall > 1e2)*(t_stall <= 1e3):
        mcsteps = int(1e4)
        threshold = 1.9e-2
    if t_stall < 3e2:
        mcsteps = int(1e4)
        #threshold = 2.5e-2
        threshold = 4e-2
    #q_list = [1e6, 1e5, 1e4, 1e3, 1e2, 1e1, 0]
    q_list = [1e5, 1e4, 1e3, 1e2, 1e1, 0]
    track_q = []
    for q in q_list:
        print('First search', q, 'T_stall', t_stall)
        track_error_s, track_speed_s, track_fpt_s, track_fptw_s, track_mu_s, \
        track_ent_s, track_time_s, track_k_s = evolve(N, L, mcsteps, T, t_stall, q, delta, n_samples, \
                                                      size, dsize, maxsize)

        track_e.append(track_error_s)
        track_S.append(track_ent_s)
        track_t.append(track_time_s)

        ent_hist = []
        for s in range(n_samples):
            #tmp =  np.asarray(track_ent_s[s])[-1]
            tmp =  np.mean(np.asarray(track_ent_s[s])[-5:])
            ent_hist.append(tmp)

        print(np.mean(ent_hist))
        if abs(np.mean(ent_hist)) > threshold:
            print("Entropy is more than: ", threshold, "Cost: ", q, 'T_stall', t_stall)
            track_q.append(q)
            break

    for cycles in range(n_cycles):
        if track_q[-1] != 0:
            kk = [6, 5, 4, 3, 2, 1, -1]
        if track_q[-1] == 0:
            kk = [6, 5, 4, 3, 2, 1, 0.1]
        if (cycles==1)*(track_q[-1] < 1e1):
            break
            
        q_list = []
        for k in range(len(kk)):
            if track_q[-1] != 0:
                q_list.append( track_q[-1] + kk[k]*0.1*track_q[-1] )
            if track_q[-1] == 0:
                q_list.append( track_q[-1] + kk[k] )
        print('New list of costs: ', q_list)

        for q in q_list:
            print('Cycle %d search'%(cycles), q, 'T_stall', t_stall)

            track_error_s, track_speed_s, track_fpt_s, track_fptw_s, track_mu_s, \
            track_ent_s, track_time_s, track_k_s = evolve(N, L, mcsteps, T, t_stall, q, delta, n_samples, \
                                                          size, dsize, maxsize)

            track_e.append(track_error_s)
            track_S.append(track_ent_s)
            track_t.append(track_time_s)

            # Entropy increase
            ent_hist = []
            for s in range(n_samples):
                #tmp =  np.asarray(track_ent_s[s])[-1]
                tmp = np.mean(np.asarray(track_ent_s[s])[-5:])
                ent_hist.append(tmp)

            print(np.mean(ent_hist))
            if abs(np.mean(ent_hist)) > threshold:
                print("Entropy is more than: ", threshold, "Cost: ", q, 'T_stall', t_stall)
                track_q.append(q)
                break
    cost.append(track_q[-1])
    stalling.append(t_stall)
# Out:
# First search 100000.0 T_stall 50.0
# 4.3351394291691024e-08
# First search 10000.0 T_stall 50.0
# 5.254500790470599e-07
# First search 1000.0 T_stall 50.0

# %% [markdown]
# Saving the data

# %%
# import pickle
# trajs = [stalling, cost]
# with open('entropy_cost_50p.pickle', 'wb') as handle:
#     pickle.dump(trajs, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Plotting the data

# %%
fig, ax = plt.subplots(figsize=(5, 5))
line = np.linspace(1e1, 1e5, 100)
ax.plot(stalling, cost, '*', color = 'black',markersize=15)
ax.plot(line, line, '--', color='gray', alpha=0.3)
ax.set_xlabel(r'Stalling time $t_{stall}$')
ax.set_ylabel(r'Crossover cost $\lambda_c$')
ax.set_xscale('log')
ax.set_xlim([4e1, 4e4])
ax.set_yscale('log')

# %% [markdown]
# #### Loading the data saved from the code above

# %%
import pickle
with open('/Users/ravasio/Documents/Chicago/Tradeoff theory/Stalling/Saved data/discrimination_cost_50p.pickle', 'rb') as handle:
    trajs = pickle.load(handle)

stalling_1 = trajs[0]
cost_1 = trajs[1]

with open('/Users/ravasio/Documents/Chicago/Tradeoff theory/Stalling/Saved data/entropy_cost_50p.pickle', 'rb') as handle:
    trajs = pickle.load(handle)

stalling = trajs[0]
cost = trajs[1]

# %%
fig, ax = plt.subplots(figsize=(4.9, 5))
line = np.linspace(1e1, 1e5, 100)
ax.plot(stalling_1, cost_1, 'o', color = '#C7A2A6',markersize=15, alpha=0.7, label = r'Error rate')
ax.plot(stalling, cost, '*', color = 'black',markersize=15, label = r'Dissipation')
ax.plot(line, 0.01*line**2, '--', color='gray', alpha=0.3)
ax.set_xlabel('Stalling time')
ax.set_ylabel('Crossover cost')
ax.set_xscale('log')
ax.set_xlim([4e1, 4e4])
ax.set_yscale('log')
ax.legend(frameon=False)
ax.set_ylim([0.5,2*1e6])
fig.tight_layout()
#plt.savefig('dissipation_cost_22.pdf')
